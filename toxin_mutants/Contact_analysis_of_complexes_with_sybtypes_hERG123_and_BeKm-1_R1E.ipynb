# %%
import pandas as pd

#Auxiliary lists of titles
columns1 = ['Molecular block number 1', 'Molecule number 1', 'Serial number of a residue 1', 
            'Title of a residue 1', 'PDB number of a residue 1']
columns2 = ['Molecular block number 2', 'Molecule number 2', 'Serial number of a residue 2', 
            'Title of a residue 2', 'PDB number of a residue 2']
necessary_columns = ['Title of a residue 1', 'PDB number of a residue 1',
              'Title of a residue 2', 'PDB number of a residue 2', 'Molecular block number 2','Duration']

names = ['a', 'b', 'Duration', 'c']
durations = ['Duration 3', 'Duration 5', 'Duration 8']

#Assign function which processes data from Nikolay csv file
def process_of_data(data):
    return pd.concat([pd.DataFrame(data.a.str.split().tolist(),
                                 columns = columns1), pd.DataFrame(data.b.str.split().tolist(),
                                 columns = columns2), pd.DataFrame(data.Duration)], axis=1)

#Assign filter function, extracting appropritate data from pandas DataFrame
def extract_appropriate_data(dataframe, duration_of_interaction = 0.1):
    return dataframe[(((pd.to_numeric(dataframe['Molecular block number 1']) == 8) & 
                       (pd.to_numeric(dataframe['Molecular block number 2']) != 8)) | 
                       ((pd.to_numeric(dataframe['Molecular block number 1']) != 8) & 
                       (pd.to_numeric(dataframe['Molecular block number 2']) == 8))) &
                    (pd.to_numeric(dataframe['Duration']) > duration_of_interaction)]

# %% [markdown]
# # hERG1

# %%
label = "hERG1"
data1 = pd.read_csv("./BeKm-1_R1E_subtypes/" + label + "/md.tpr_hb_ft.csv", names=names)
data2 = pd.read_csv("./BeKm-1_R1E_subtypes/" + label + "/md.tpr_pi_ft.csv", names=names)
data3 = pd.read_csv("./BeKm-1_R1E_subtypes/" + label + "/md.tpr_sb_ft.csv", names=names)
data4 = pd.read_csv("./BeKm-1_R1E_subtypes/" + label + "/md.tpr_stk_ft.csv", names=names)
data5 = pd.read_csv("./BeKm-1_R1E_subtypes/" + label + "/md.tpr_phob_ft.csv", names=names)

hb = extract_appropriate_data(process_of_data(data1))[necessary_columns].reset_index(drop=True)
pi = extract_appropriate_data(process_of_data(data2))[necessary_columns].reset_index(drop=True)
sb = extract_appropriate_data(process_of_data(data3))[necessary_columns].reset_index(drop=True)
stk = extract_appropriate_data(process_of_data(data4))[necessary_columns].reset_index(drop=True)
phob = extract_appropriate_data(process_of_data(data5))[necessary_columns].reset_index(drop=True)

# %%
hb
# Out:
#    Title of a residue 1 PDB number of a residue 1 Title of a residue 2  \
# 0                   GLY                        22                  GLY
# 1                   ARG                        20                  GLN
# 2                   PHE                        36                  GLN
# 3                   PHE                        21                  SER
# 4                   LYS                        18                  SER
# 5                   ASN                        25                  ASN
# 6                   GLU                         9                  ARG
# 7                   ARG                        27                  ASP
# 8                   GLU                         1                  ARG
# 9                   ARG                        27                  ASP
# 10                  GLY                        26                  ASN
# 11                  LYS                        23                  ASN
# 12                  GLU                         1                  ASP
# 13                  PHE                        36                  ASN
# 14                  ASN                        25                  ASN
# 15                  SER                        10                  ASP
# 16                  LYS                        18                  GLY
# 17                  LYS                        23                  ASN
# 18                  THR                        24                  GLY
# 19                  TYR                        11                  ASN
# 20                  LYS                        18                  ASN
# 21                  LYS                        18                  ASN
# 22                  ASP                         4                  ARG
# 23                  LYS                        18                  SER
# 24                  THR                        24                  SER
#
#    PDB number of a residue 2 Molecular block number 2  Duration
# 0                        628                        1  0.862138
# 1                        592                        1  0.852148
# 2                        592                        7  0.823177
# 3                        631                        7  0.672328
# 4                        631                        1  0.643357
# 5                        629                        5  0.615385
# 6                        582                        3  0.604396
# 7                        591                        5  0.544456
# 8                        582                        7  0.539461
# 9                        580                        5  0.453546
# 10                       588                        5  0.429570
# 11                       588                        7  0.400599
# 12                       591                        7  0.392607
# 13                       588                        7  0.341658
# 14                       588                        5  0.326673
# 15                       591                        5  0.295704
# 16                       628                        5  0.283716
# 17                       629                        7  0.273726
# 18                       628                        7  0.228771
# 19                       588                        3  0.202797
# 20                       588                        3  0.165834
# 21                       629                        3  0.162837
# 22                       582                        1  0.149850
# 23                       631                        3  0.135864
# 24                       631                        5  0.115884

# %%
sb
# Out:
#   Title of a residue 1 PDB number of a residue 1 Title of a residue 2  \
# 0                  ARG                        20                  ASP
# 1                  GLU                         9                  ARG
# 2                  GLU                         1                  ARG
# 3                  GLU                         1                  ASP
# 4                  ARG                        27                  ASP
# 5                  ARG                        27                  ASP
# 6                  ASP                         4                  ARG
#
#   PDB number of a residue 2 Molecular block number 2  Duration
# 0                       591                        1  0.839161
# 1                       582                        3  0.629371
# 2                       582                        7  0.560440
# 3                       591                        7  0.558442
# 4                       580                        5  0.558442
# 5                       591                        5  0.548452
# 6                       582                        1  0.171828

# %%
pi
# Out:
#   Title of a residue 1 PDB number of a residue 1 Title of a residue 2  \
# 0                  TYR                        11                  ARG
# 1                  PHE                        36                  ARG
# 2                  ARG                        27                  HIS
#
#   PDB number of a residue 2 Molecular block number 2  Duration
# 0                       582                        3  0.840160
# 1                       582                        5  0.669331
# 2                       587                        5  0.415584

# %%
stk
# Out:
#   Title of a residue 1 PDB number of a residue 1 Title of a residue 2  \
# 0                  TYR                        11                  ARG
# 1                  PHE                        36                  ARG
# 2                  PHE                        36                  HIS
# 3                  ARG                        27                  HIS
# 4                  ARG                        27                  ARG
#
#   PDB number of a residue 2 Molecular block number 2  Duration
# 0                       582                        3  0.507493
# 1                       582                        5  0.387612
# 2                       587                        5  0.279720
# 3                       587                        5  0.143856
# 4                       582                        5  0.107892

# %% [markdown]
# # hERG2

# %%
label = "hERG2"
data1 = pd.read_csv("./BeKm-1_R1E_subtypes/" + label + "/md.tpr_hb_ft.csv", names=names)
data2 = pd.read_csv("./BeKm-1_R1E_subtypes/" + label + "/md.tpr_pi_ft.csv", names=names)
data3 = pd.read_csv("./BeKm-1_R1E_subtypes/" + label + "/md.tpr_sb_ft.csv", names=names)
data4 = pd.read_csv("./BeKm-1_R1E_subtypes/" + label + "/md.tpr_stk_ft.csv", names=names)
data5 = pd.read_csv("./BeKm-1_R1E_subtypes/" + label + "/md.tpr_phob_ft.csv", names=names)

hb = extract_appropriate_data(process_of_data(data1))[necessary_columns].reset_index(drop=True)
pi = extract_appropriate_data(process_of_data(data2))[necessary_columns].reset_index(drop=True)
sb = extract_appropriate_data(process_of_data(data3))[necessary_columns].reset_index(drop=True)
stk = extract_appropriate_data(process_of_data(data4))[necessary_columns].reset_index(drop=True)
phob = extract_appropriate_data(process_of_data(data5))[necessary_columns].reset_index(drop=True)

# %%
hb
# Out:
#    Title of a residue 1 PDB number of a residue 1 Title of a residue 2  \
# 0                   ARG                        20                  GLN
# 1                   ASP                         4                  ARG
# 2                   ARG                        27                  GLU
# 3                   PRO                        15                  GLN
# 4                   ASP                        34                  ARG
# 5                   GLU                         9                  LYS
# 6                   TYR                        11                  ASP
# 7                   PHE                        36                  SER
# 8                   SER                        19                  SER
# 9                   SER                        19                  ASN
# 10                  ARG                        20                  ASP
# 11                  LYS                        18                  SER
# 12                  GLU                         1                  ARG
# 13                  LYS                        23                  SER
# 14                  ASN                        25                  SER
# 15                  LYS                        18                  GLY
#
#    PDB number of a residue 2 Molecular block number 2  Duration
# 0                        443                        1  0.868132
# 1                        447                        1  0.825175
# 2                        431                        5  0.811189
# 3                        443                        3  0.745255
# 4                        447                        7  0.677323
# 5                        433                        3  0.630370
# 6                        438                        3  0.517483
# 7                        439                        7  0.391608
# 8                        483                        1  0.363636
# 9                        481                        3  0.311688
# 10                       438                        1  0.305694
# 11                       483                        1  0.280719
# 12                       447                        7  0.256743
# 13                       439                        7  0.157842
# 14                       439                        5  0.157842
# 15                       480                        3  0.144855

# %%
sb
# Out:
#   Title of a residue 1 PDB number of a residue 1 Title of a residue 2  \
# 0                  ASP                         4                  ARG
# 1                  ARG                        27                  GLU
# 2                  ASP                        34                  ARG
# 3                  GLU                         9                  LYS
# 4                  ARG                        20                  ASP
# 5                  GLU                         1                  ARG
# 6                  ARG                        27                  ASP
#
#   PDB number of a residue 2 Molecular block number 2  Duration
# 0                       447                        1  0.867133
# 1                       431                        5  0.834166
# 2                       447                        7  0.765235
# 3                       433                        3  0.688312
# 4                       438                        1  0.359640
# 5                       447                        7  0.328671
# 6                       438                        5  0.173826

# %%
pi
# Out:
#   Title of a residue 1 PDB number of a residue 1 Title of a residue 2  \
# 0                  LYS                        18                  PHE
# 1                  TYR                        11                  LYS
# 2                  TYR                        11                  ARG
# 3                  LYS                        18                  PHE
# 4                  PHE                        36                  ARG
# 5                  PHE                        36                  LYS
#
#   PDB number of a residue 2 Molecular block number 2  Duration
# 0                       479                        3  0.665335
# 1                       433                        3  0.646354
# 2                       447                        3  0.554446
# 3                       479                        1  0.449550
# 4                       447                        7  0.217782
# 5                       433                        5  0.136863

# %%
stk
# Out:
#   Title of a residue 1 PDB number of a residue 1 Title of a residue 2  \
# 0                  ARG                        20                  ARG
# 1                  TYR                        11                  ARG
# 2                  ARG                        27                  ARG
#
#   PDB number of a residue 2 Molecular block number 2  Duration
# 0                       447                        1  0.220779
# 1                       447                        3  0.214785
# 2                       447                        5  0.173826

# %% [markdown]
# # hERG3

# %%
label = "hERG3"
data1 = pd.read_csv("./BeKm-1_R1E_subtypes/" + label + "/md.tpr_hb_ft.csv", names=names)
data2 = pd.read_csv("./BeKm-1_R1E_subtypes/" + label + "/md.tpr_pi_ft.csv", names=names)
data3 = pd.read_csv("./BeKm-1_R1E_subtypes/" + label + "/md.tpr_sb_ft.csv", names=names)
data4 = pd.read_csv("./BeKm-1_R1E_subtypes/" + label + "/md.tpr_stk_ft.csv", names=names)
data5 = pd.read_csv("./BeKm-1_R1E_subtypes/" + label + "/md.tpr_phob_ft.csv", names=names)

hb = extract_appropriate_data(process_of_data(data1))[necessary_columns].reset_index(drop=True)
pi = extract_appropriate_data(process_of_data(data2))[necessary_columns].reset_index(drop=True)
sb = extract_appropriate_data(process_of_data(data3))[necessary_columns].reset_index(drop=True)
stk = extract_appropriate_data(process_of_data(data4))[necessary_columns].reset_index(drop=True)
phob = extract_appropriate_data(process_of_data(data5))[necessary_columns].reset_index(drop=True)

# %%
hb
# Out:
#    Title of a residue 1 PDB number of a residue 1 Title of a residue 2  \
# 0                   PHE                        36                  GLN
# 1                   LYS                        18                  GLY
# 2                   ASP                        34                  GLN
# 3                   GLU                         9                  ARG
# 4                   LYS                        18                  GLY
# 5                   ARG                        20                  GLN
# 6                   ARG                        20                  ASP
# 7                   THR                        24                  SER
# 8                   SER                        19                  ASN
# 9                   ARG                        20                  GLN
# 10                  LYS                        18                  SER
# 11                  GLU                         1                  ARG
# 12                  ASN                        25                  ASN
# 13                  ARG                        27                  ASP
# 14                  LYS                        18                  SER
# 15                  SER                        10                  GLN
# 16                  GLY                        22                  GLY
# 17                  SER                        10                  SER
# 18                  LYS                        23                  GLY
# 19                  LYS                        23                  SER
# 20                  GLU                         1                  GLN
# 21                  ARG                        20                  LYS
# 22                  ARG                        27                  ASP
# 23                  ARG                        27                  GLN
# 24                  ASN                        25                  SER
# 25                  ASN                        25                  ASP
# 26                  ASP                        34                  ARG
# 27                  ARG                        27                  GLN
# 28                  SER                        19                  SER
#
#    PDB number of a residue 2 Molecular block number 2  Duration
# 0                        594                        7  0.968032
# 1                        631                        3  0.869131
# 2                        593                        7  0.748252
# 3                        598                        5  0.722278
# 4                        631                        5  0.721279
# 5                        594                        1  0.713287
# 6                        589                        1  0.710290
# 7                        634                        5  0.699301
# 8                        636                        1  0.671329
# 9                        593                        1  0.646354
# 10                       634                        1  0.553447
# 11                       598                        7  0.466533
# 12                       632                        5  0.419580
# 13                       589                        5  0.379620
# 14                       634                        3  0.348651
# 15                       593                        5  0.319680
# 16                       631                        1  0.312687
# 17                       590                        5  0.249750
# 18                       631                        1  0.198801
# 19                       634                        7  0.198801
# 20                       593                        7  0.163836
# 21                       584                        1  0.156843
# 22                       583                        5  0.156843
# 23                       594                        7  0.151848
# 24                       634                        5  0.138861
# 25                       589                        5  0.124875
# 26                       598                        7  0.116883
# 27                       593                        7  0.116883
# 28                       634                        1  0.100899

# %%
sb
# Out:
#   Title of a residue 1 PDB number of a residue 1 Title of a residue 2  \
# 0                  GLU                         9                  ARG
# 1                  ARG                        20                  ASP
# 2                  GLU                         1                  ARG
# 3                  ARG                        27                  ASP
# 4                  ARG                        27                  ASP
# 5                  ASP                        34                  ARG
#
#   PDB number of a residue 2 Molecular block number 2  Duration
# 0                       598                        5  0.764236
# 1                       589                        1  0.727273
# 2                       598                        7  0.484515
# 3                       589                        5  0.410589
# 4                       583                        5  0.188811
# 5                       598                        7  0.128871

# %%
pi
# Out:
#   Title of a residue 1 PDB number of a residue 1 Title of a residue 2  \
# 0                  LYS                        18                  PHE
#
#   PDB number of a residue 2 Molecular block number 2  Duration
# 0                       630                        3    0.2997

# %%
stk
# Out:
# Empty DataFrame
# Columns: [Title of a residue 1, PDB number of a residue 1, Title of a residue 2, PDB number of a residue 2, Molecular block number 2, Duration]
# Index: []
