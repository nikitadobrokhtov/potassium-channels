# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
EAGn = pd.read_csv("/home/nikita/D/Potassium channels/for_all/EAG/energy_analisys/all_rtotal.csv")
EAG4 = pd.read_csv("./BeKm-1_PHE14-SER_ARG20-LYS_ARG27-LYS_PHE36-LYS_amydated/energy_analysis/all_rtotal.csv")

# %%
bekm1_res_num = [i for i in range(1, 38)]
BeKm_1= ['ARG1','PRO2','THR3','ASP4','ILE5','LYS6','CYS7','SER8','GLU9','SER10','TYR11','GLN12','CYS13','PHE14','PRO15','VAL16','CYS17','LYS18','SER19','ARG20','PHE21','GLY22','LYS23','THR24','ASN25','GLY26','ARG27','CYS28','VAL29','ASN30','GLY31','PHE32','CYS33','ASP34','CYS35','PHE36', 'NH2']

# %% [markdown]
# # BeKm-1_PHE14-SER_ARG20-LYS_ARG27-LYS_PHE36-LYS_amydated

# %%
EAGn_data = list(EAGn[' full'])
EAG4_data = list(EAG4[' full'])

EAGn_error = list(EAGn[' stdfull'])
EAG4_error = list(EAG4[' stdfull'])

EAGn_data.append(0)
EAGn_error.append(0)

plotdata = pd.DataFrame({
    "EAGn":EAGn_data,
    "EAG4":EAG4_data
    }, 
    index=BeKm_1
)
ploterror = pd.DataFrame({
    "EAGn":EAGn_data,
    "EAG4":EAG4_data
    }, 
    index=BeKm_1
)

plotdata.plot(kind="bar", figsize=(20,15), yerr=ploterror)
plt.title("PHE14 -> SER; ARG20 -> LYS; ARG27 -> LYS; PHE36 -> LYSam", fontsize=20, color='red')
plt.xlabel("BeKm-1 residues' numbers", fontsize=14)
plt.ylabel("Full energy", fontsize=14)
plt.savefig("rERG2_rERG3")
plt.show()
