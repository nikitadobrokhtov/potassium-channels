# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def RMS_from_xvg(path, skip_beg=18, skip_end=1):
    with open(path, "r") as myFile:
        data = [[float(i) for i in line.strip().split('    ')] for line in myFile.read().split('\n')[skip_beg:(skip_end * (-1))]]
    return [x[1] for x in data]

# %%
def plot_xvg(path, label, data_size, skip_beg=18, skip_end=1):
    def RMS_from_xvg(path, skip_beg, skip_end):
        with open(path, "r") as myFile:
            data = [[float(i) for i in line.strip().split('    ')] for line in myFile.read().split('\n')[skip_beg:(skip_end * (-1))]]
        return [x[0] for x in data], [x[1] for x in data]
    x, y = RMS_from_xvg(path, skip_beg, skip_end)
    plt.plot(x[:data_size], y[:data_size], label=label)

# %%
fig = plt.figure(figsize=(12,9))

plot_xvg("/home/nikita/D/Potassium channels/for_all/hERG1/pictures/RMSD_rec_rel_rec.xvg", label="hERG1", data_size=1001)
plot_xvg("/home/nikita/D/Potassium channels/for_all/EAG/pictures/RMSD_rec_rel_rec.xvg", label="EAG", data_size=1001)



plt.xlim(0, 100000)

plt.legend()
plt.xlabel("Time, ps", fontsize=14)
plt.ylabel("RMSD", fontsize=14)
plt.title("RMSD Receptor on Receptor", color='red', fontsize=20)

plt.show()

# %%
fig = plt.figure(figsize=(12,9))

plot_xvg("/home/nikita/D/Potassium channels/for_all/hERG1/pictures/RMSD_tox_rel_rec.xvg", label="hERG1", data_size=1001)
plot_xvg("/home/nikita/D/Potassium channels/for_all/EAG/pictures/RMSD_tox_rel_rec.xvg", label="EAG", data_size=1001)



plt.xlim(0, 100000)

plt.legend()
plt.xlabel("Time, ps", fontsize=14)
plt.ylabel("RMSD", fontsize=14)
plt.title("RMSD Ligand on Receptor", color='red', fontsize=20)

plt.show()

# %%
fig = plt.figure(figsize=(12,9))

plot_xvg("/home/nikita/D/Potassium channels/for_all/hERG1/pictures/RMSD_tox_rel_tox.xvg", label="hERG1", data_size=1001)
plot_xvg("/home/nikita/D/Potassium channels/for_all/EAG/pictures/RMSD_tox_rel_tox.xvg", label="EAG", data_size=1001)



plt.xlim(0, 100000)

plt.legend()
plt.xlabel("Time, ps", fontsize=14)
plt.ylabel("RMSD", fontsize=14)
plt.title("RMSD Ligand on Ligand", color='red', fontsize=20)

plt.show()

# %%
def xvg_data(path, skip_beg=17, skip_end=1):
    def RMS_from_xvg(path, skip_beg, skip_end):
        with open(path, "r") as myFile:
            data = [[float(i) for i in line.strip().split('   ')] for line in myFile.read().split('\n')[skip_beg:(skip_end * (-1))]]
        return [x[0] for x in data], [x[1] for x in data]
    x, y = RMS_from_xvg(path, skip_beg, skip_end)
    return y

# %%
fig = plt.figure(figsize=(12,9))

toxin_atoms=[i for i in range(1, 548)]

plt.plot(toxin_atoms, xvg_data("/home/nikita/D/Potassium channels/for_all/hERG1/pictures/RMSF_tox.xvg"), label="hERG1")
plt.plot(toxin_atoms, xvg_data("/home/nikita/D/Potassium channels/for_all/EAG/pictures/RMSF_tox.xvg"), label="EAG")




plt.legend()
plt.xlabel("Atoms in ligand", fontsize=14)
plt.ylabel("RMSD", fontsize=14)
plt.title("RMSF Ligand", color='red', fontsize=20)

plt.show()
